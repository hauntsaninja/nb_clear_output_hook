# %%
# this cell output should be kept

print("hi, i am a small output")
# Out:
# hi, i am a small output

# %%
# this cell output should be cleared

import matplotlib.pyplot as plt
import numpy as np

# Create 1000 random data points
x = np.random.rand(1000)
y = np.random.rand(1000)

# Map each data point to a color based on its x and y values
colors = np.sqrt(x ** 2 + y ** 2)

# Map each data point to a size based on its distance from the origin
sizes = colors * 10

# Create a scatter plot with the data points, colors, and sizes
plt.figure(figsize=(4, 4))
plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap="hsv")
plt.colorbar() # show color scale
plt.show()

# %%
# this cell output should be kept

from IPython.display import HTML

# Define the HTML code for a table with two rows and two columns
table_html = """
<table>
  <tr>
    <th>Column 1</th>
    <th>Column 2</th>
  </tr>
  <tr>
    <td>Row 1, Cell 1</td>
    <td>Row 1, Cell 2</td>
  </tr>
  <tr>
    <td>Row 2, Cell 1</td>
    <td>Row 2, Cell 2</td>
  </tr>
</table>
"""

# Display the HTML table
HTML(table_html)
# Out:
# <table>
#   <tr>
#     <th>Column 1</th>
#     <th>Column 2</th>
#   </tr>
#   <tr>
#     <td>Row 1, Cell 1</td>
#     <td>Row 1, Cell 2</td>
#   </tr>
#   <tr>
#     <td>Row 2, Cell 1</td>
#     <td>Row 2, Cell 2</td>
#   </tr>
# </table>

# %%
# this cell output should be kept

from PIL import Image, ImageDraw

# Create a new image with a white background
img = Image.new("RGB", (50, 50), "white")
draw = ImageDraw.Draw(img)

# Draw a black square on the image
draw.rectangle((10, 10, 40, 40), fill="black")

# Display the image
img
# Out:
# <PIL.Image.Image image mode=RGB size=50x50>

# %%
# this cell output should be cleared

import random
import string

# Define a list of all possible characters (uppercase and lowercase letters, digits, punctuation)
chars = string.ascii_letters + string.digits + string.punctuation

# Generate a random string with 2000 characters
text = "".join(random.Random(0).choices(chars, k=2000))

# Print the string
print(text)
# Out:
# <*NyWM,CS2\VA*6x\}/[D'[#SjO5\{S>y.Zb&L:!aU>wE>r1w{.QhEV^kZ%Z/Y{43P4K2Brr59Si*?]<[]YK%z/<[3`2Q!~]-h5T7<w'lu-F/jn$e1\Y"c742KI}dc{rlt._cOjyu8GqVdj}sH';]p"{f"<Gx4PqSM1VDH;x0b(FeAw`HBH`76&KM9asFw7J?1ML$N!ePyoXT0*@UDR/?/r~7h'}L"Du&a:Xjl9?A|j=LhzQ-=mW9G>Abd#0__\d)$9%[8JYt3aoF-&F6dp}BLZBSweqXgLEMj\S<|GT$OC([]6J|8gh)faLWQT2"NI}y,OHg>$[Q"lLtd`unsJZo}}nM"?U]EUU!s5uF{[/dny,<2&.gh>dvdb<Fpn9|V[V1".*~)\tY4:T-K3=.9arVxg=_CM/f8lA;fdNU>&"o}M5KeSod67jZGK+U?5R7Fl#6-l\.]?#/W,r,P*Q-he^T[_!1ui:@,$NCkO1]^Nj+(cP#c]{&hgHcGa|/g@tt"_laIc4=rkG{m{ISB_{7r~j2o[_.Dw)BN