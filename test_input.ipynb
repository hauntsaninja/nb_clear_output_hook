# %%
# this cell output should be kept

print("hi, i am a small output")
# Out:
# hi, i am a small output

# %%
# this cell output should be cleared

import matplotlib.pyplot as plt
import numpy as np

# Create 1000 random data points
x = np.random.rand(1000)
y = np.random.rand(1000)

# Map each data point to a color based on its x and y values
colors = np.sqrt(x ** 2 + y ** 2)

# Map each data point to a size based on its distance from the origin
sizes = colors * 100

# Create a scatter plot with the data points, colors, and sizes
plt.figure(figsize=(10, 10))
plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap="hsv")
plt.colorbar() # show color scale
plt.show()

# %%
# this cell output should be kept

from IPython.display import HTML

# Define the HTML code for a table with two rows and two columns
table_html = """
<table>
  <tr>
    <th>Column 1</th>
    <th>Column 2</th>
  </tr>
  <tr>
    <td>Row 1, Cell 1</td>
    <td>Row 1, Cell 2</td>
  </tr>
  <tr>
    <td>Row 2, Cell 1</td>
    <td>Row 2, Cell 2</td>
  </tr>
</table>
"""

# Display the HTML table
HTML(table_html)
# Out:
# <table>
#   <tr>
#     <th>Column 1</th>
#     <th>Column 2</th>
#   </tr>
#   <tr>
#     <td>Row 1, Cell 1</td>
#     <td>Row 1, Cell 2</td>
#   </tr>
#   <tr>
#     <td>Row 2, Cell 1</td>
#     <td>Row 2, Cell 2</td>
#   </tr>
# </table>

# %%
# this should not be cleared

from PIL import Image, ImageDraw

# Create a new image with a white background
img = Image.new("RGB", (50, 50), "white")
draw = ImageDraw.Draw(img)

# Draw a black square on the image
draw.rectangle((10, 10, 40, 40), fill="black")

# Display the image
img
# Out:
# <PIL.Image.Image image mode=RGB size=50x50 at 0x7FDFF5AA7D50>

# %%
# this should be cleared

import random
import string

# Define a list of all possible characters (uppercase and lowercase letters, digits, punctuation)
chars = string.ascii_letters + string.digits + string.punctuation

# Generate a random string with 100,000 characters
text = "".join(random.choices(chars, k=100000))

# Print the string
print(text)
# Out:
# z<-6nSA!*nItvLNRfbNIf&n+jo\h^"loZ8vq6}Z,Veo{!:efb73*2<"ejw}?J9QEv(uM>&!f`!"V!x4ZN`j.+G_3~84o-)*h.X?<vUYaIw~_TPY&ck:bf6.6t<3n>aK!O-X8{G.s?I25F!O]Y'B[|-1Ws>ZtilT1eQd7.!d#4bnC7M!08JM;~H4.%q_&d>Ro.C?WZ2K.]:k)KES@uP}FdG(rQ.LNNQ.`@VMwgBxg0]+{:\8WN09g6]3Icp^{84K:E$8[]*qad]O@_r-fq;s-+'>4GfBDd!3lNP|/Jzc3Q&kcW:8sC$JJL^B!9{V(c&YsI-&.;m_\(_|BkOsqvD2r;&nu\c8$d`RIZ89:fV=q\^?>DR):/!#_44)=`_)oh8VC'5l'if@)_(!Dz2$mL[^Hal@O;}`$)ZYX,-{nXZrexoFY>O=w8_xu}q@[dq^L+(Gv[!y>4JN0o`d"Z~~kO<(=keVBt]|:W=+MMUG$a,a[m!dPVa`c)m}LH*Wz~.KuXKKXD+0[(g}Ml*-ikh'Ht_he"w/Glo>~g{HOJ?{w'NU$8c<0n"k&M)%@.}I&b&9|zq0(zqX0y.@_--mpQP433h~!k?'NeQ6g9JSN4@!wr"@f$X!"mKay<B4]rL2%\3-'\NJSlgJc(^*8g3l|Tx;bh@ZIQ><@[`s-Foxan'Mg+sez@FA?r-EEGvPG(F_Jok9k^Y